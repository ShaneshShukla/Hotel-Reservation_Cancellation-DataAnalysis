# %% [markdown]
# ### Hotel Reservation Cancellation Analysis Report
#
# #### Introduction
# In this report, we analyze hotel reservation cancellation data to gain insights into booking trends, cancellation rates, and factors influencing cancellations. The analysis is based on data collected from hotel reservations using Python, pandas, NumPy, Matplotlib, Seaborn, and Jupyter Notebook.
#
# #### Findings and Analysis
#
# 1. **Cancellation Rate Overview**
#    - A bar graph illustrates the percentage of reservations canceled versus those that were not. Approximately 37% of clients canceled their reservations, indicating a significant impact on hotel earnings.
#
# 2. **Comparison between Resort and City Hotels**
#    - City hotels exhibit higher booking volumes compared to resort hotels, suggesting a possible preference for city accommodations due to their affordability.
#
# 3. **Average Daily Rate (ADR) Comparison**
#    - A line graph depicts fluctuations in the average daily rate between city and resort hotels. It is observed that resort hotel rates may increase during weekends and holidays.
#
# 4. **Monthly Reservation Analysis**
#    - A grouped bar graph analyzes reservation levels by month and status. August registers the highest number of both confirmed and canceled reservations, while January has the highest number of cancellations.
#
# 5. **Impact of Price on Cancellations**
#    - A bar graph illustrates the correlation between cancellation frequency and accommodation prices. Cancellations are more prevalent when prices are higher, suggesting that cost influences cancellation decisions.
#
# 6. **Top 10 Countries with Highest Cancellation Rates**
#    - A pie chart highlights the top 10 countries with the highest cancellation rates, with Portugal (PTR) accounting for 70.1% of cancellations. Recommendations include targeted campaigns and promotional offers to mitigate cancellation rates from these countries.
#
# 7. **Reservation Source Analysis**
#    - Analysis reveals that 46% of clients book through online travel agencies, while 27% come from groups. Direct bookings account for only 4% of reservations.
#
# 8. **Relationship between Price and Cancellations**
#    - Reservations are more likely to be canceled when the average daily rate is higher, confirming the influence of price on cancellation behavior.
#
# #### Suggestions
# Based on the findings, the following suggestions are proposed for hotel management:
# - Implement targeted marketing campaigns and promotional offers to reduce cancellation rates, particularly from countries with high cancellation rates like Portugal.
# - Optimize pricing strategies to mitigate cancellations, considering that higher prices correlate with increased cancellation frequency.
# - Strengthen partnerships with online travel agencies and group booking channels to maximize reservation opportunities.
#
# #### Conclusion
# The analysis provides valuable insights into hotel reservation cancellations, highlighting the importance of understanding booking trends and factors influencing cancellations. By leveraging these insights, hotels can develop strategies to optimize revenue and enhance guest satisfaction.

# %% [markdown]
# # importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # reading the CSV file

# %%
#pd.read_csv() is a function provided by the pandas library in Python used to read comma-separated values (CSV) files into a DataFrame.
df = pd.read_csv("hotel_bookings 2.csv")

# %% [markdown]
# # Dataset Study

# %%
#The df.head() method in pandas is used to display the first few rows of a DataFrame.
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#The df.head() method in pandas is used to display the last few rows of a DataFrame.
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
#it returns the number of rows and columns in the DataFrame.
df.shape
# Out:
# (119390, 32)

# %%
# includes  information about the index dtype and columns, non-null values, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# It provides information such as count, mean, standard deviation, minimum, maximum, and various percentiles of the data distribution for each numerical column.
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include = "object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
#finding the unique values in every object type column
for col in df.describe(include = "object").columns:
    print(col)
    print(df[col].unique())
    print("-"*30)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
#df.columns is an attribute in pandas DataFrame objects that returns a list-like object containing the column labels of the DataFrame.
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# # data Cleaning

# %%
# changing the type of reservation_status_date from object to datatime.
df["reservation_status_date"] = pd.to_datetime(df["reservation_status_date"],format='mixed')

# %%
# isnull() function used to find null/nan values in dataset
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# isnull() function has shown that agent and company column has many nan/mising values 
df.drop(["company","agent"],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
#now there is o missing/nan values in dataset
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# hear you can see the one value in adr column is 5400 which is an outlier for our analysis
df  = df[df["adr"] <5000]

# %% [markdown]
# # Data Analysis  and Visualization

# %%
percentage_cancelled=df["is_canceled"].value_counts(normalize = True)
plt.figure(figsize=(5,4))
sns.barplot(data)
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
df.groupby("reservation_status")

# %%
percentage_cancelled=df["is_canceled"].value_counts(normalize = True)
print(percentage_cancelled)
reservation = sns.countplot(x="reservation_status",hue="reservation_status",data = df,palette='YlOrBr');
for bars in reservation.containers:
    reservation.bar_label(bars)
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %% [markdown]
# The accompanying bar graph shows the percentage of reservations that are canceled and those that are not. It is obvious that there are still a significant number of reservations that have not been canceled. There are still 37% of clients who canceled their reservation, which has a significant impact on the hotels earnings.

# %%
ax1=sns.countplot(x="hotel",hue="is_canceled",data=df,palette="YlOrBr")
plt.title("Reservation Status in Diffrent Hotels",size=10)
plt.ylabel("Number Of Reservation")
# Out:
# Text(0, 0.5, 'Number Of Reservation')

# %% [markdown]
# In comparison to resort hotels, city hotels have more bookings. It's possible that resort hotels are more expensive than those in cities.

# %%
#reservation and cancellation percentage at Resort Hoptel
df.groupby("hotel").get_group("Resort Hotel")["is_canceled"].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
#reservation and cancellation percentage at City Hotel
df.groupby("hotel").get_group("City Hotel")["is_canceled"].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %%
xresort=df.groupby("hotel").get_group("Resort Hotel")
xresort=xresort.groupby("reservation_status_date")[["adr"]].mean()
xcity=df.groupby("hotel").get_group("City Hotel")
xcity=xcity.groupby("reservation_status_date")[["adr"]].mean()

# %%
plt.figure(figsize=(20,8))
plt.title("Average Daily Rate in City and Resort hotel",size=30)
plt.plot(xresort.index,xresort["adr"],label="Resort Hotel")
plt.plot(xcity.index,xcity["adr"],label="City Hotel")
plt.legend(fontsize=17)
plt.show()

# %% [markdown]
# The line graph above shows that, on certain days, the average daily rate for a city hotel is less than that of a resort hotel, and on other days, it is even less. It goes without
# saying that weekends and holidays may see a rise in resort hotel rates.

# %%
df["month"]= df["reservation_status_date"].dt.month
plt.figure(figsize=(17,5))
sns.countplot(x="month",hue="is_canceled",data=df,palette="YlOrBr");
plt.title("Reservation and Cancellation Status per Month",size=20)
plt.xlabel("Arrival Month",size=12)
plt.ylabel("Number of Reservations",size=12)
plt.show()

# %% [markdown]
# We have developed the grouped bar graph to analyze the months with the highest and lowest reservation levels according to reservation status. As can be seen, both the number of confirmed reservations and the number of canceled reservations are largest in the month of August. whereas January is the month with the most canceled reservations.

# %%
x=df[df["is_canceled"] == 1].groupby("month",as_index=False)["adr"].sum()
plt.figure(figsize=(12,5))
sns.barplot(x="month",y="adr",hue="month",legend=False,data=x,palette="YlOrBr");
plt.ylabel("adr",size=11)
plt.xlabel("Month",size=11)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This bar graph demonstrates that cancellations are most common when prices are greatest and are least common when they are lowest. Therefore, the cost of the accommodation is solely responsible for the cancellation.

# %%
country_can = df[df["is_canceled"] == 1].groupby("country").size().nlargest(10)
colors = sns.color_palette("YlOrBr")
plt.figure(figsize=(7,7))
plt.pie(country_can, labels=country_can.index, autopct='%1.1f%%', startangle=140,colors=colors)
plt.title('Top 20 Countries with Cancellations')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# from above pie chart show you top 10 countries in case of cancellation rate, in which 70.1% cancellation is from Portugal(PTR). thus, hotel management need to focus on this and run some campaign , promotional offers by which they can minimise this cancellation rates.

# %%
# market segment total numbers by bookings
df["market_segment"].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
# in percentage
df["market_segment"].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
# this will give us cancellation rate by market segment 
marseg_can =df[df["is_canceled"]==1]["market_segment"].value_counts().reset_index()
plt.figure(figsize=(10,5))
sns.barplot(x="market_segment",y="count",hue="market_segment",legend=False,data=marseg_can,palette="YlOrBr")
plt.title("Cancellation Rate by Market Segment",size=12)
plt.ylabel("Number of cancellations",size=12)
plt.xlabel("Market Segment",size=12)
# Out:
# Text(0.5, 0, 'Market Segment')

# %% [markdown]
# Let's check the area from where guests are visiting the hotels and making reservations. Is it coming from Direct or Groups, Online or Offline Travel Agents? Around 46% of the clients come from online travel agencies, whereas 27% come from groups. Only 4% of clients book hotels directly by visiting them and making reservations.

# %%
canres_adr=df[df["is_canceled"]==1].groupby("reservation_status_date")[["adr"]].mean().sort_values(by="reservation_status_date").reset_index()
noncanres_adr=df[df["is_canceled"]==0].groupby("reservation_status_date")[["adr"]].mean().sort_values(by="reservation_status_date").reset_index()
plt.figure(figsize=(20,8))
plt.title("Average Daily Rate",size=18)
plt.plot(noncanres_adr["reservation_status_date"],noncanres_adr["adr"],label="Not Canceled")
plt.plot(canres_adr["reservation_status_date"],canres_adr["adr"],label="cancelled")
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# As seen in the graph, reservations are canceled when the average daily rate is higher than when it is not canceled. It clearly proves all the above analysis, that the higher
# price leads to higher cancellation.
